# %%
import requests
import json
import pandas as pd

url = "https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones/"

querystring = {"api_key": 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJiYXJ0dWxvQGdtYWlsLmNvbSIsImp0aSI6IjNlYjNjZjY2LTFkZDktNDE4OC04NjQ0LWVhYmVhZGIxMGMxNCIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjA5NjU0NDU2LCJ1c2VySWQiOiIzZWIzY2Y2Ni0xZGQ5LTQxODgtODY0NC1lYWJlYWRiMTBjMTQiLCJyb2xlIjoiIn0.xg7Q5NhTAnWyv_BADoRRGN-g-nUmgBgHTBfvDbJyP30'}
headers = {
    'cache-control': "no-cache"
}

response = requests.request("GET", url, headers=headers, params=querystring)
url_datos = json.loads(response.text)['datos']

response_datos = requests.request("GET", url_datos)
datos = json.loads(response_datos.text)

df = pd.DataFrame(datos)
display(df.loc[df['provincia'] == 'STA. CRUZ DE TENERIFE'])
# Out:
#      latitud              provincia altitud indicativo  \
# 281  281906N  STA. CRUZ DE TENERIFE     115      C439J
# 282  274908N  STA. CRUZ DE TENERIFE      32      C929I
# 283  281832N  STA. CRUZ DE TENERIFE    2371      C430E
# 284  283759N  STA. CRUZ DE TENERIFE      33      C139E
# 285  282505N  STA. CRUZ DE TENERIFE      25      C459Z
# 286  280523N  STA. CRUZ DE TENERIFE      15      C329Z
# 287  282748N  STA. CRUZ DE TENERIFE      35      C449C
# 288  283545N  STA. CRUZ DE TENERIFE      62      C129Z
# 289  282839N  STA. CRUZ DE TENERIFE     632      C447A
# 290  280249N  STA. CRUZ DE TENERIFE      64      C429I
#
#                          nombre indsinop longitud
# 281                      GÜÍMAR    60018  162256W
# 282           HIERRO AEROPUERTO    60001  175320W
# 283                       IZAÑA    60010  162958W
# 284         LA PALMA AEROPUERTO    60005  174518W
# 285           PUERTO DE LA CRUZ    60012  163253W
# 286  SAN SEBASTIÁN DE LA GOMERA    60008  170641W
# 287        STA.CRUZ DE TENERIFE    60020  161519W
# 288                   TAZACORTE    60004  175455W
# 289   TENERIFE NORTE AEROPUERTO    60015  161946W
# 290     TENERIFE SUR AEROPUERTO    60025  163340W

# %%
u = 'https://opendata.aemet.es/opendata/api/observacion/convencional/datos/estacion/C139E'
r = requests.request("GET", u, headers=headers, params=querystring)
d = json.loads(r.text)['datos']

a = requests.request("GET", d)
b = pd.DataFrame(json.loads(a.text))
display(b)
# Out:
#     idema        lon                 fint  prec   alt  vmax   vv     dv  \
# 0   C139E -17.755005  2021-02-12T21:00:00   0.0  33.0   6.7  3.5  310.0
# 1   C139E -17.755005  2021-02-12T22:00:00   0.0  33.0   8.2  4.2  320.0
