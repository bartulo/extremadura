# %%
import psycopg2
import geopandas as gpd
import matplotlib.pyplot as plt
from config import config
import matplotlib.patches as patches
import cartopy.crs as ccrs
from labellines import *

params = config()
conn = psycopg2.connect(**params)

# proj = ccrs.epsg('25830')
proj = ccrs.TransverseMercator(central_longitude=-3.0,central_latitude=0.0,
                           false_easting=500000.0,false_northing=0.0,
                           scale_factor=0.9996)
buffer = 1000

zonas = ['jerte', 'tornavacas', 'losar', 'madrigal', 'losar']
for zona in zonas:
    # IMAGEN CUENCA
    cuenca = gpd.read_postgis("select * from cuencas where nombre = 'Cuenca del Tajo'", conn)
    ze = gpd.read_postgis('select * from zona_estudio_{}'.format(zona), conn)
    rios_ppales = gpd.read_postgis("select * from rios where cuenca = 'Cuenca del Tajo' and categoria = 1", conn)
    rios = gpd.read_postgis('''
                        select 
                        row_number() over (order by a.long_km desc), a.* 
                        from rios a, zona_estudio_{} b 
                        where st_intersects(a.geom, b.geom) 
                        and a.long_km < 50
                        '''.format(zona), conn)
    display(rios)
    
    fig = plt.figure(figsize=(24,18))
    ax = plt.axes(projection=proj)
    
    lim = list(cuenca.bounds.iloc[0])
    ax.set_extent([lim[0] - buffer,lim[2] + buffer, lim[1] - buffer , lim[3] + buffer], crs=proj)
    
    xvals = []
    for index, rio in rios_ppales.iterrows():
        for r in rio['geom']:
            plt.plot(r.xy[0], r.xy[1], label=rio['nombre'])
            xvals.append(r.xy[0][int(len(r.xy[0]) / 2)])        
    
    labelLines(plt.gca().get_lines(), xvals=xvals, fontsize=20, zorder=2.5)
    
    plt.subplot(ax)
    ax.add_geometries(cuenca['geom'], crs=proj, facecolor=(0, 0, 0, 0), edgecolor='black')
    plt.subplot(ax)
    ax.add_geometries(ze['geom'], crs=proj, facecolor=(0,0,0,0), edgecolor='red')
    
    plt.subplot(ax)
#     ax.add_wms(wms='https://servicios.idee.es/wms-inspire/mdt', layers=['sombreado'])
    lim_rios = rios.bounds.min()['miny']
    lim_ze = ze.bounds.iloc[0]
    rect = patches.Rectangle((lim_ze[0] - buffer, lim_rios - buffer), #origen
                             (lim_ze[2] - lim_ze[0]) + 2 * buffer, #ancho
                             (lim_ze[3] - lim_rios) + 2 * buffer, #alto
                             linewidth=4, edgecolor='r', facecolor='none')
    ax.add_patch(rect)

#     fig.savefig('static/images/hidrografia_cuenca_{}'.format(zona), bbox_inches='tight', pad_inches=0)
    plt.show()
    plt.close(fig)
    
    # IMAGEN DETALLE
    fig = plt.figure(figsize=(24,18))
    ax = plt.axes(projection=proj)
    
    ax.set_extent([lim_ze[0] - buffer, lim_ze[2] + buffer, lim_rios - buffer, lim_ze[3] + buffer], crs=proj)
    
    xvals = []
    for index, rio in rios.iterrows():
        for ri in rio['geom']:
            plt.plot(ri.xy[0], ri.xy[1], label=rio['row_number'], color='blue')
            xvals.append(ri.xy[0][int(len(ri.xy[0]) /2)])
    
    labelLines(plt.gca().get_lines(), xvals=xvals, fontsize=25, zorder=2.5)

    plt.subplot(ax)
#     ax.add_wms(wms='https://servicios.idee.es/wms-inspire/mdt', layers=['sombreado'])

    plt.subplot(ax)
    ax.add_geometries(ze['geom'], crs=proj, facecolor=(0,0,0,0), edgecolor='red')
    
    plt.subplot(ax)
    rios_ppales.plot(ax=ax)
    
#     fig.savefig('static/images/hidrografia_detalle_{}'.format(zona), bbox_inches='tight', pad_inches=0)
    plt.show()
    plt.close(fig)
    
conn.close()
# Out:
#    row_number   gid           cuenca tipo_curso               nombre nombre2  \
# 0           1  1969  Cuenca del Tajo   Garganta  Garganta las Papuas    None
# 1           2   131  Cuenca del Tajo     Arroyo      Arroyo Majacero    None
#
#    categoria  long_km                                               geom
# 0          3  6.29165  MULTILINESTRING ((266295.689 4456146.823, 2662...
# 1          3  2.32514  MULTILINESTRING ((268234.682 4461243.878, 2682...
#    row_number   gid           cuenca tipo_curso                  nombre  \
# 0           1  1844  Cuenca del Tajo   Garganta         Garganta Beceda
# 1           2   187  Cuenca del Tajo     Arroyo    Arroyo Regajo Grande
# 2           3  1868  Cuenca del Tajo   Garganta  Garganta de Calvarrasa
# 3           4   131  Cuenca del Tajo     Arroyo         Arroyo Majacero
# 4           5    28  Cuenca del Tajo     Arroyo        Arroyo Banquillo
# 5           6  1974  Cuenca del Tajo       Hoya          Hoya Talamanca
#
#             nombre2  categoria  long_km  \
# 0              None          3  5.97850
# 1  Arroyo Tejadillo          3  4.03184
# 2              None          3  3.68231
# 3              None          3  2.32514
# 4              None          3  2.20370
# 5              None          3  1.84395
#
#                                                 geom
# 0  MULTILINESTRING ((268836.808 4457744.402, 2688...
# 1  MULTILINESTRING ((268739.494 4460222.156, 2687...
# 2  MULTILINESTRING ((270390.196 4458758.862, 2703...
# 3  MULTILINESTRING ((268234.682 4461243.878, 2682...
# 4  MULTILINESTRING ((268618.002 4459953.657, 2686...
# 5  MULTILINESTRING ((269164.203 4461559.225, 2691...
#     row_number   gid           cuenca tipo_curso  \
# 0            1  1872  Cuenca del Tajo   Garganta
# 1            2  1902  Cuenca del Tajo   Garganta
# 2            3  1873  Cuenca del Tajo   Garganta
# 3            4  1949  Cuenca del Tajo   Garganta
# 4            5  1945  Cuenca del Tajo   Garganta
# 5            6  1936  Cuenca del Tajo   Garganta
# 6            7  1145  Cuenca del Tajo     Arroyo
# 7            8  1879  Cuenca del Tajo   Garganta
# 8            9   633  Cuenca del Tajo     Arroyo
# 9           10   582  Cuenca del Tajo     Arroyo
# 10          11   941  Cuenca del Tajo     Arroyo
# 11          12   449  Cuenca del Tajo     Arroyo
# 12          13  1516  Cuenca del Tajo     Arroyo
# 13          14  2419  Cuenca del Tajo  Vertiente
# 14          15  1150  Cuenca del Tajo     Arroyo
# 15          16   585  Cuenca del Tajo     Arroyo
# 16          17   420  Cuenca del Tajo     Arroyo
# 17          18  2436  Cuenca del Tajo  Vertiente
# 18          19  2430  Cuenca del Tajo  Vertiente
#
#                           nombre                  nombre2  categoria  \
# 0            Garganta de Cuartos                     None          2
# 1             Garganta de la Hoz                     None          2
# 2          Garganta de Cuaternas    Garganta de las Meñas          3
# 3         Garganta del Largarejo        Garganta Barreros          3
# 4          Garganta del Hortigal                     None          3
# 5          Garganta del Corzogal  Garganta de Caballerías          3
# 6         Arroyo de las Covachas        Arroyo Escobajero          3
# 7         Garganta de Largaderas                     None          3
# 8            Arroyo de Toro Alto                     None          3
# 9               Arroyo de Ripias                     None          3
# 10         Arroyo de la Labranza                     None          3
# 11       Arroyo de Majada Alonso                     None          3
# 12             Arroyo del Gitano                     None          3
# 13           Vertiente Hormigoso                     None          3
# 14         Arroyo de las Cumbres                     None          3
# 15           Arroyo de Rocerecos                     None          3
# 16          Arroyo de Horquillas                     None          3
# 17  Vertiente de las Zahurdillas                     None          3
# 18     Vertiente de la Lanchuela                     None          3
#
#      long_km                                               geom
# 0   24.43420  MULTILINESTRING ((281305.485 4436195.726, 2813...
# 1   13.44820  MULTILINESTRING ((294226.864 4448569.326, 2942...
# 2    5.71602  MULTILINESTRING ((281809.756 4448501.661, 2818...
# 3    3.06770  MULTILINESTRING ((279555.006 4451950.456, 2795...
# 4    2.92371  MULTILINESTRING ((279596.557 4451595.875, 2796...
# 5    2.85068  MULTILINESTRING ((279616.744 4450778.007, 2796...
# 6    2.32426  MULTILINESTRING ((278629.918 4452775.218, 2786...
# 7    2.22361  MULTILINESTRING ((278380.420 4448403.291, 2783...
# 8    1.97619  MULTILINESTRING ((278877.418 4452385.926, 2788...
# 9    1.95094  MULTILINESTRING ((280153.862 4450001.503, 2801...
# 10   1.63606  MULTILINESTRING ((283953.485 4450908.529, 2839...
# 11   1.60438  MULTILINESTRING ((279764.921 4451768.747, 2797...
# 12   1.55266  MULTILINESTRING ((282073.752 4451571.654, 2820...
# 13   1.38178  MULTILINESTRING ((280923.379 4448956.165, 2809...
# 14   1.32310  MULTILINESTRING ((282091.720 4451959.447, 2820...
# 15   1.29081  MULTILINESTRING ((283059.720 4449180.396, 2830...
# 16   1.18928  MULTILINESTRING ((281736.126 4452122.452, 2817...
# 17   1.09751  MULTILINESTRING ((280905.518 4448843.898, 2809...
# 18   1.06860  MULTILINESTRING ((278397.118 4448222.290, 2783...
#     row_number   gid           cuenca tipo_curso                     nombre  \
# 0            1  1864  Cuenca del Tajo   Garganta        Garganta de Alardos
# 1            2  1902  Cuenca del Tajo   Garganta         Garganta de la Hoz
# 2            3  1909  Cuenca del Tajo   Garganta    Garganta de la Regadera
# 3            4  1489  Cuenca del Tajo     Arroyo        Arroyo del Encinoso
# 4            5  1086  Cuenca del Tajo     Arroyo       Arroyo de la Ventosa
# 5            6  1944  Cuenca del Tajo   Garganta       Garganta del Hornito
# 6            7  1161  Cuenca del Tajo     Arroyo      Arroyo de las Hoyitas
# 7            8   402  Cuenca del Tajo     Arroyo    Arroyo de Garganta Seca
# 8            9   137  Cuenca del Tajo     Arroyo             Arroyo Malezas
# 9           10  1511  Cuenca del Tajo     Arroyo       Arroyo del Gargantón
# 10          11   456  Cuenca del Tajo     Arroyo      Arroyo de Malos Pasos
# 11          12  1139  Cuenca del Tajo     Arroyo  Arroyo de las Cerradillas
#
#                  nombre2  categoria   long_km  \
# 0                   None          2  17.95850
# 1                   None          2  13.44820
# 2                   None          3   9.55301
# 3                   None          3   7.74813
# 4   Arroyo de la Ventera          3   5.67605
# 5                   None          3   5.60923
# 6                   None          3   3.65586
# 7                   None          3   3.43723
# 8                   None          3   2.34905
# 9                   None          3   1.57435
# 10                  None          3   1.52602
# 11                  None          3   1.50577
#
#                                                  geom
# 0   MULTILINESTRING ((301004.171 4443154.280, 3010...
# 1   MULTILINESTRING ((294226.864 4448569.326, 2942...
# 2   MULTILINESTRING ((298553.104 4451185.266, 2985...
# 3   MULTILINESTRING ((298289.858 4454324.685, 2982...
# 4   MULTILINESTRING ((291294.694 4449481.980, 2912...
# 5   MULTILINESTRING ((298505.956 4452459.157, 2984...
# 6   MULTILINESTRING ((299425.913 4456083.269, 2994...
# 7   MULTILINESTRING ((300042.052 4457641.271, 3000...
# 8   MULTILINESTRING ((292563.797 4452314.615, 2925...
# 9   MULTILINESTRING ((292219.711 4453455.088, 2922...
# 10  MULTILINESTRING ((296430.032 4455431.342, 2964...
# 11  MULTILINESTRING ((300113.232 4457845.983, 3001...
#     row_number   gid           cuenca tipo_curso  \
# 0            1  1872  Cuenca del Tajo   Garganta
# 1            2  1902  Cuenca del Tajo   Garganta
# 2            3  1873  Cuenca del Tajo   Garganta
# 3            4  1949  Cuenca del Tajo   Garganta
# 4            5  1945  Cuenca del Tajo   Garganta
# 5            6  1936  Cuenca del Tajo   Garganta
# 6            7  1145  Cuenca del Tajo     Arroyo
# 7            8  1879  Cuenca del Tajo   Garganta
# 8            9   633  Cuenca del Tajo     Arroyo
# 9           10   582  Cuenca del Tajo     Arroyo
# 10          11   941  Cuenca del Tajo     Arroyo
# 11          12   449  Cuenca del Tajo     Arroyo
# 12          13  1516  Cuenca del Tajo     Arroyo
# 13          14  2419  Cuenca del Tajo  Vertiente
# 14          15  1150  Cuenca del Tajo     Arroyo
# 15          16   585  Cuenca del Tajo     Arroyo
# 16          17   420  Cuenca del Tajo     Arroyo
# 17          18  2436  Cuenca del Tajo  Vertiente
# 18          19  2430  Cuenca del Tajo  Vertiente
#
#                           nombre                  nombre2  categoria  \
# 0            Garganta de Cuartos                     None          2
# 1             Garganta de la Hoz                     None          2
# 2          Garganta de Cuaternas    Garganta de las Meñas          3
# 3         Garganta del Largarejo        Garganta Barreros          3
# 4          Garganta del Hortigal                     None          3
# 5          Garganta del Corzogal  Garganta de Caballerías          3
# 6         Arroyo de las Covachas        Arroyo Escobajero          3
# 7         Garganta de Largaderas                     None          3
# 8            Arroyo de Toro Alto                     None          3
# 9               Arroyo de Ripias                     None          3
# 10         Arroyo de la Labranza                     None          3
# 11       Arroyo de Majada Alonso                     None          3
# 12             Arroyo del Gitano                     None          3
# 13           Vertiente Hormigoso                     None          3
# 14         Arroyo de las Cumbres                     None          3
# 15           Arroyo de Rocerecos                     None          3
# 16          Arroyo de Horquillas                     None          3
# 17  Vertiente de las Zahurdillas                     None          3
# 18     Vertiente de la Lanchuela                     None          3
#
#      long_km                                               geom
# 0   24.43420  MULTILINESTRING ((281305.485 4436195.726, 2813...
# 1   13.44820  MULTILINESTRING ((294226.864 4448569.326, 2942...
# 2    5.71602  MULTILINESTRING ((281809.756 4448501.661, 2818...
# 3    3.06770  MULTILINESTRING ((279555.006 4451950.456, 2795...
# 4    2.92371  MULTILINESTRING ((279596.557 4451595.875, 2796...
# 5    2.85068  MULTILINESTRING ((279616.744 4450778.007, 2796...
# 6    2.32426  MULTILINESTRING ((278629.918 4452775.218, 2786...
# 7    2.22361  MULTILINESTRING ((278380.420 4448403.291, 2783...
# 8    1.97619  MULTILINESTRING ((278877.418 4452385.926, 2788...
# 9    1.95094  MULTILINESTRING ((280153.862 4450001.503, 2801...
# 10   1.63606  MULTILINESTRING ((283953.485 4450908.529, 2839...
# 11   1.60438  MULTILINESTRING ((279764.921 4451768.747, 2797...
# 12   1.55266  MULTILINESTRING ((282073.752 4451571.654, 2820...
# 13   1.38178  MULTILINESTRING ((280923.379 4448956.165, 2809...
# 14   1.32310  MULTILINESTRING ((282091.720 4451959.447, 2820...
# 15   1.29081  MULTILINESTRING ((283059.720 4449180.396, 2830...
# 16   1.18928  MULTILINESTRING ((281736.126 4452122.452, 2817...
# 17   1.09751  MULTILINESTRING ((280905.518 4448843.898, 2809...
# 18   1.06860  MULTILINESTRING ((278397.118 4448222.290, 2783...

# %%
from osgeo import gdal
import numpy as np
# IMAGEN DETALLE
fig = plt.figure(figsize=(24,18))
ax = plt.axes(projection=proj, label='prueba')

ax.set_extent([lim_ze[0] - buffer, lim_ze[2] + buffer, lim_rios - buffer, lim_ze[3] + buffer], crs=proj)

xvals = []
for index, rio in rios.iterrows():
    for ri in rio['geom']:
        plt.plot(ri.xy[0], ri.xy[1], label=rio['row_number'], color='blue')
        xvals.append(ri.xy[0][int(len(ri.xy[0]) /2)])

labelLines(plt.gca().get_lines(), xvals=xvals, fontsize=25, zorder=2.5)

plt.subplot(ax)
# ax.add_wms(wms='https://servicios.idee.es/wms-inspire/mdt', layers=['sombreado'])

plt.subplot(ax)
ax.add_geometries(ze['geom'], crs=proj, facecolor=(0,0,0,0), edgecolor='red', linewidth=4, zorder=100)

plt.subplot(ax)
rios_ppales.plot(ax=ax)

display(lim_rios)
gdal_data = gdal.Open('../BRUTOS/mdt/mdt_combinado.tif')
gdal.Translate('static/prueba.tif', gdal_data, projWin = (lim_ze['minx'] - buffer, lim_ze['maxy'] + buffer, lim_ze['maxx'] + buffer, lim_rios - buffer))

mdt = gdal.Open('static/prueba.tif')

data_array = mdt.ReadAsArray().astype(np.float)
mdt_array = np.flipud(data_array)

plt.subplot(ax)
ax.contour(mdt_array, cmap='terrain', levels = list(range(0,2500, 20)), 
           extent=(lim_ze['minx'] - buffer, lim_ze['maxx'] + buffer, lim_rios - buffer, lim_ze['maxy'] + buffer))
#     fig.savefig('static/images/hidrografia_detalle_{}'.format(zona), bbox_inches='tight', pad_inches=0)
plt.show()
# plt.close(fig)
# Out:
# 4436195.725693214
