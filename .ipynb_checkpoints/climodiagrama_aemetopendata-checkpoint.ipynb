# %%
import requests
import json
import pandas as pd

url = "https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones/"

querystring = {"api_key": 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJiYXJ0dWxvQGdtYWlsLmNvbSIsImp0aSI6IjNlYjNjZjY2LTFkZDktNDE4OC04NjQ0LWVhYmVhZGIxMGMxNCIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjA5NjU0NDU2LCJ1c2VySWQiOiIzZWIzY2Y2Ni0xZGQ5LTQxODgtODY0NC1lYWJlYWRiMTBjMTQiLCJyb2xlIjoiIn0.xg7Q5NhTAnWyv_BADoRRGN-g-nUmgBgHTBfvDbJyP30'}
headers = {
    'cache-control': "no-cache"
}

response = requests.request("GET", url, headers=headers, params=querystring)
url_datos = json.loads(response.text)['datos']

response_datos = requests.request("GET", url_datos)
datos = json.loads(response_datos.text)

df = pd.DataFrame(datos)
print(df.loc[df['provincia'] == 'AVILA'])
# Out:
#     latitud provincia altitud indicativo                  nombre indsinop  \
# 63  403924N     AVILA    1143      2444C     ÁVILA, AYUNTAMIENTO
# 64  403933N     AVILA    1130       2444                   ÁVILA    08210
# 65  402102N     AVILA    1525      2811A  NAVARREDONDA DE GREDOS    08206
# 93  401719N     AVILA     630       3391    SOTILLO DE LA ADRADA    08208
#
#    longitud
# 63  044201W
# 64  044048W
# 65  050835W
# 93  043527W

# %%
u = 'https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2016-01-01T00:00:00UTC/fechafin/2016-01-31T00:00:00UTC/estacion/2811A'
r = requests.request("GET", u, headers=headers, params=querystring)
d = json.loads(r.text)['datos']

a = requests.request("GET", d)
b = pd.DataFrame(json.loads(a.text))
display(b)
# Out:
#          fecha indicativo                  nombre provincia altitud  tmed  \
# 0   2016-01-01      2811A  NAVARREDONDA DE GREDOS     AVILA    1525   6,6
# 1   2016-01-02      2811A  NAVARREDONDA DE GREDOS     AVILA    1525   1,8
# 2   2016-01-03      2811A  NAVARREDONDA DE GREDOS     AVILA    1525   3,8
# 3   2016-01-04      2811A  NAVARREDONDA DE GREDOS     AVILA    1525   6,8
# 4   2016-01-05      2811A  NAVARREDONDA DE GREDOS     AVILA    1525   0,0
# 5   2016-01-06      2811A  NAVARREDONDA DE GREDOS     AVILA    1525   1,2
# 6   2016-01-07      2811A  NAVARREDONDA DE GREDOS     AVILA    1525   8,0
# 7   2016-01-08      2811A  NAVARREDONDA DE GREDOS     AVILA    1525   7,0
# 8   2016-01-09      2811A  NAVARREDONDA DE GREDOS     AVILA    1525   4,8
# 9   2016-01-10      2811A  NAVARREDONDA DE GREDOS     AVILA    1525   5,2
# 10  2016-01-11      2811A  NAVARREDONDA DE GREDOS     AVILA    1525   2,6
# 11  2016-01-12      2811A  NAVARREDONDA DE GREDOS     AVILA    1525   0,6
# ...
